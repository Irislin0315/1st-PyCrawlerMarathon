# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %% [markdown]
# r.text是將送出請求獲得的資料轉為string，json.loads(r.text)執行完則是list。

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
# Requests GET
import requests
r = requests.get('http://odata.wra.gov.tw/v4/RealtimeWaterLevel')
r.text
# Out:
# '{"@odata.context": "http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel",\n"@odata.count": 100,\n"value": [{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "2560H020","WaterLevel": 0.14},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "2420H019","WaterLevel": 109.94},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "1660H013","WaterLevel": 0.88},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "1660H011","WaterLevel": 1.47},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "2370H025","WaterLevel": 261.63},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "1730H062","WaterLevel": 41.74},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "1740H011","WaterLevel": 6.61},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "1740H010","WaterLevel": 47.04},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "1660H009","WaterLevel": 4.82},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "2370H019","WaterLevel": 156.05},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "1730H067","WaterLevel": -999998},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "1740H008","WaterLevel": 1.1},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "1730H057","WaterLevel": 43.46},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "1650H013","WaterLevel": 5.66},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "2370H004","WaterLevel": 192.67},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "1730H036","WaterLevel": 107.43},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "1740H002","WaterLevel": 4.42},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "1680H005","WaterLevel": 0.06},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "1650H009","WaterLevel": 0.18},{"RecordTime": "Dec 4, 2019 1:20:00 PM","StationIdentifier": "1630H032","WaterLevel": 0.28},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "2560H017","WaterLevel": 366.39},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "1650H014","WaterLevel": 0.92},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "1580H020","WaterLevel": 35.36},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "1670H004","WaterLevel": 2.99},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "1630H036","WaterLevel": 65.8},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "2420H036","WaterLevel": 164.36},{"RecordTime": "Dec 4, 2019 1:20:00 PM","StationIdentifier": "1630H028","WaterLevel": 10.25},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "2500H003","WaterLevel": 32.08},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "2370H017","WaterLevel": 58.5},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "1580H013","WaterLevel": 9.71},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "1550H014","WaterLevel": 26.76},{"RecordTime": "Dec 4, 2019 1:20:00 PM","StationIdentifier": "1630H033","WaterLevel": 0.14},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "1650H011","WaterLevel": 0.26},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "1630H024","WaterLevel": 69.09},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "1650H006","WaterLevel": 1.18},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "2200H028","WaterLevel": 277.72},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "1550H018","WaterLevel": 0.3},{"RecordTime": "Dec 4, 2019 1:20:00 PM","StationIdentifier": "1630H030","WaterLevel": 1.55},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "1510H081","WaterLevel": 229.08},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "1540H014","WaterLevel": 7.95},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "1630H005","WaterLevel": 39.76},{"RecordTime": "Dec 4, 2019 2:10:00 PM","StationIdentifier": "1540H033","WaterLevel": 23 ...

# %%
# json load
import json

json.loads(r.text)
# Out:
# {'@odata.context': 'http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel',
#  '@odata.count': 100,
#  'value': [{'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '2560H020',
#    'WaterLevel': 0.14},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '2420H019',
#    'WaterLevel': 109.94},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1660H013',
#    'WaterLevel': 0.88},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1660H011',
#    'WaterLevel': 1.47},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '2370H025',
#    'WaterLevel': 261.63},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1730H062',
#    'WaterLevel': 41.74},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1740H011',
#    'WaterLevel': 6.61},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1740H010',
#    'WaterLevel': 47.04},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1660H009',
#    'WaterLevel': 4.82},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '2370H019',
#    'WaterLevel': 156.05},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1730H067',
#    'WaterLevel': -999998},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1740H008',
#    'WaterLevel': 1.1},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1730H057',
#    'WaterLevel': 43.46},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1650H013',
#    'WaterLevel': 5.66},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '2370H004',
#    'WaterLevel': 192.67},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1730H036',
#    'WaterLevel': 107.43},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1740H002',
#    'WaterLevel': 4.42},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1680H005',
#    'WaterLevel': 0.06},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1650H009',
#    'WaterLevel': 0.18},
#   {'RecordTime': 'Dec 4, 2019 1:20:00 PM',
#    'StationIdentifier': '1630H032',
#    'WaterLevel': 0.28},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '2560H017',
#    'WaterLevel': 366.39},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1650H014',
#    'WaterLevel': 0.92},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1580H020',
#    'WaterLevel': 35.36},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1670H004',
#    'WaterLevel': 2.99},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1630H036',
#    'WaterLevel': 65.8},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '2420H036',
#    'WaterLevel': 164.36},
#   {'RecordTime': 'Dec 4, 2019 1:20:00 PM',
#    'StationIdentifier': '1630H028',
#    'WaterLevel': 10.25},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '2500H003',
#    'WaterLevel': 32.08},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '2370H017',
#    'WaterLevel': 58.5},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1580H013',
#    'WaterLevel': 9.71},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1550H014',
#    'WaterLevel': 26.76},
#   {'RecordTime': 'Dec 4, 2019 1:20:00 PM',
#    'StationIdentifier': '1630H033',
#    'WaterLevel': 0.14},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1650H011',
#    'WaterLevel': 0.26},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1630H024',
#    'WaterLevel': 69.09},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1650H006',
#    'WaterLevel': 1.18},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '2200H028',
#    'WaterLevel': 277.72},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1550H018',
#    'WaterLevel': 0.3},
#   {'RecordTime': 'Dec 4, 2019 1:20:00 PM',
#    'StationIdentifier': '1630H030',
#    'WaterLevel': 1.55},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1510H081',
#    'WaterLevel': 229.08},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1540H014',
#    'WaterLevel': 7.95},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1630H005',
#    'WaterLevel': 39.76},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1540H033',
#    'WaterLevel': 23.3},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1630H018',
#    'WaterLevel': 10.01},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1550H011',
#    'WaterLevel': -0.14},
#   {'RecordTime': 'Dec 4, 2019 1:20:00 PM',
#    'StationIdentifier': '1630H026',
#    'WaterLevel': 44.48},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1510H057',
#    'WaterLevel': 88.49},
#   {'RecordTime': 'Dec 4, 2019 1:50:00 PM',
#    'StationIdentifier': '1510H083',
#    'WaterLevel': 116.61},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1590H013',
#    'WaterLevel': 20.74},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1540H029',
#    'WaterLevel': 12.78},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1590H019',
#    'WaterLevel': 14.87},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1540H038',
#    'WaterLevel': 54.79},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1630H020',
#    'WaterLevel': 35.27},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1510H049',
#    'WaterLevel': 470.81},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1510H079',
#    'WaterLevel': 187.7},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1580H021',
#    'WaterLevel': 1.25},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1580H017',
#    'WaterLevel': 25.73},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1520H008',
#    'WaterLevel': 78.22},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1540H036',
#    'WaterLevel': 0.43},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1430H053',
#    'WaterLevel': 38.45},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1430H060',
#    'WaterLevel': 20.07},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1510H076',
#    'WaterLevel': 4.9},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1430H032',
#    'WaterLevel': 337.55},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1580H007',
#    'WaterLevel': 23.64},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1510H088',
#    'WaterLevel': 141.08},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1540H031',
#    'WaterLevel': 10.09},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1430H048',
#    'WaterLevel': 165.98},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1430H055',
#    'WaterLevel': 78.57},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1510H064',
#    'WaterLevel': 264.97},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1430H029',
#    'WaterLevel': 50.61},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1550H016',
#    'WaterLevel': 12.25},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1510H085',
#    'WaterLevel': 279.78},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1430H044',
#    'WaterLevel': 139.47},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1350H031',
#    'WaterLevel': -0.01},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1430H045',
#    'WaterLevel': 91.64},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1430H057',
#    'WaterLevel': 31.71},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1430H025',
#    'WaterLevel': 9.95},
#   {'RecordTime': 'Dec 4, 2019 2:00:00 PM',
#    'StationIdentifier': '1420H053',
#    'WaterLevel': 471.57},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1510H071',
#    'WaterLevel': 20.67},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1420H057',
#    'WaterLevel': 639.42},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1350H028',
#    'WaterLevel': 232.59},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1430H038',
#    'WaterLevel': 74.79},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1340H014',
#    'WaterLevel': 0.24},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1400H015',
#    'WaterLevel': 624.92},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1420H049',
#    'WaterLevel': 54.14},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1350H021',
#    'WaterLevel': 319.72},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1420H055',
#    'WaterLevel': 318.95},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1350H024',
#    'WaterLevel': 259.64},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1300H024',
#    'WaterLevel': 28.81},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1340H010',
#    'WaterLevel': 0.6},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1400H008',
#    'WaterLevel': 479.64},
#   {'RecordTime': 'Dec 4, 2019 2:00:00 PM',
#    'StationIdentifier': '1400H019',
#    'WaterLevel': 310.14},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1350H018',
#    'WaterLevel': 282.04},
#   {'RecordTime': 'Dec 4, 2019 2:00:00 PM',
#    'StationIdentifier': '1140H110',
#    'WaterLevel': 42.38},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1400H012',
#    'WaterLevel': 598.85},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1290H007',
#    'WaterLevel': 12.81},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1320H001',
#    'WaterLevel': 2.6},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1140H096',
#    'WaterLevel': 170.53},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1350H019',
#    'WaterLevel': 33.68},
#   {'RecordTime': 'Dec 4, 2019 2:10:00 PM',
#    'StationIdentifier': '1340H012',
#    'WaterLevel': 246.84},
#   {'RecordTime': 'Dec 4, 2019 2:00:00 PM',
#    'StationIdentifier': '1140H066',
#    'WaterLevel': 1.98}],
#  '@odata.nextLink': 'http://odata.wra.gov.tw/v4/RealtimeWaterLevel?$skip=100&$top=100'}

# %%
# Requests POST
r = requests.post('https://cat-fact.herokuapp.com/facts', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'message': 'Sign in first'}
